# %% [markdown]
# # Simple linear regression

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
sns.set()

# %%
pip install numpy
# Out:
# Collecting numpy
#   Downloading numpy-1.25.1-cp39-cp39-macosx_10_9_x86_64.whl (20.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.1/20.1 MB 31.5 MB/s eta 0:00:0000:0100:01
# Installing collected packages: numpy
# Successfully installed numpy-1.25.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 3.8 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from seaborn) (1.25.0)
# Requirement already satisfied: pandas>=0.25 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from seaborn) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (6.0.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install pandas
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
#
#
#
# ## Package Plan ##
#
#   environment location: /Users/ashleybodine/anaconda3/envs/modeling
#
#   added / updated specs:
#     - pandas
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |              mkl           6 KB
#     ------------------------------------------------------------
#                                            Total:           6 KB
#
# The following NEW packages will be INSTALLED:
#
#   blas               pkgs/main/osx-64::blas-1.0-mkl
#   bottleneck         pkgs/main/osx-64::bottleneck-1.3.5-py39h67323c0_0
#   intel-openmp       pkgs/main/osx-64::intel-openmp-2023.1.0-ha357a0b_43547
#   mkl                pkgs/main/osx-64::mkl-2023.1.0-h59209a4_43558
#   mkl-service        pkgs/main/osx-64::mkl-service-2.4.0-py39h6c40b1e_1
#   mkl_fft            pkgs/main/osx-64::mkl_fft-1.3.6-py39h07fba90_1
#   mkl_random         pkgs/main/osx-64::mkl_random-1.2.2-py39h07fba90_1
#   numexpr            pkgs/main/osx-64::numexpr-2.8.4-py39h47b59a4_1
#   numpy              pkgs/main/osx-64::numpy-1.25.0-py39h827a554_0
#   numpy-base         pkgs/main/osx-64::numpy-base-1.25.0-py39ha186be2_0
#   pandas             pkgs/main/osx-64::pandas-1.5.3-py39h07fba90_0
#   pytz               pkgs/main/osx-64::pytz-2022.7-py39hecd8cb5_0
#   tbb                pkgs/main/osx-64::tbb-2021.8.0-ha357a0b_0
#
#
#
# Downloading and Extracting Packages
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda update -n base -c defaults conda

# %%
pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.7.2-cp39-cp39-macosx_10_12_x86_64.whl (7.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 16.8 MB/s eta 0:00:0000:0100:01
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.1.0-cp39-cp39-macosx_10_9_x86_64.whl (243 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.40.0-cp39-cp39-macosx_10_9_x86_64.whl (2.1 MB)
# Collecting kiwisolver>=1.0.1 (from matplotlib)
#   Using cached kiwisolver-1.4.4-cp39-cp39-macosx_10_9_x86_64.whl (65 kB)
# Requirement already satisfied: numpy>=1.20 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib) (1.25.0)
# Requirement already satisfied: packaging>=20.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib) (23.0)
# Collecting pillow>=6.2.0 (from matplotlib)
#   Downloading Pillow-10.0.0-cp39-cp39-macosx_10_10_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 13.9 MB/s eta 0:00:0000:0100:01
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.0.9-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.3/98.3 kB 2.0 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: python-dateutil>=2.7 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting importlib-resources>=3.2.0 (from matplotlib)
#   Downloading importlib_resources-6.0.0-py3-none-any.whl (31 kB)
# Requirement already satisfied: zipp>=3.1.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.11.0)
# Requirement already satisfied: six>=1.5 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: pyparsing, pillow, kiwisolver, importlib-resources, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.1.0 cycler-0.11.0 fonttools-4.40.0 importlib-resources-6.0.0 kiwisolver-1.4.4 matplotlib-3.7.2 pillow-10.0.0 pyparsing-3.0.9
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda statsmodels
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/ashleybodine/anaconda3/envs/modeling
#
#   added / updated specs:
#     - statsmodels
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     appdirs-1.4.4              |     pyhd3eb1b0_0          12 KB  anaconda
#     brotlipy-0.7.0             |py39h9ed2024_1003         359 KB  anaconda
#     certifi-2022.6.15          |   py39hecd8cb5_0         157 KB  anaconda
#     charset-normalizer-2.0.4   |     pyhd3eb1b0_0          33 KB  anaconda
#     cryptography-37.0.1        |   py39hf6deb26_0         1.2 MB  anaconda
#     llvm-openmp-12.0.0         |       h0dcd299_1         300 KB  anaconda
#     patsy-0.5.2                |   py39hecd8cb5_1         378 KB  anaconda
#     pooch-1.4.0                |     pyhd3eb1b0_0          41 KB  anaconda
#     pyopenssl-22.0.0           |     pyhd3eb1b0_0          49 KB  anaconda
#     pysocks-1.7.1              |   py39hecd8cb5_0          30 KB  anaconda
#     requests-2.27.1            |     pyhd3eb1b0_0          52 KB  anaconda
#     scipy-1.10.1               |   py39hf241641_1        21.1 MB
#     statsmodels-0.13.2         |   py39hca72f7f_0        10.7 MB  anaconda
#     urllib3-1.26.9             |   py39hecd8cb5_0         178 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:        34.5 MB
#
# The following NEW packages will be INSTALLED:
#
#   appdirs            anaconda/noarch::appdirs-1.4.4-pyhd3eb1b0_0
#   brotlipy           anaconda/osx-64::brotlipy-0.7.0-py39h9ed2024_1003
#   certifi            anaconda/osx-64::certifi-2022.6.15-py39hecd8cb5_0
#   charset-normalizer anaconda/noarch::charset-normalizer-2.0.4-pyhd3eb1b0_0
#   cryptography       anaconda/osx-64::cryptography-37.0.1-py39hf6deb26_0
#   libgfortran        pkgs/main/osx-64::libgfortran-5.0.0-11_3_0_hecd8cb5_28
#   libgfortran5       pkgs/main/osx-64::libgfortran5-11.3.0-h9dfd629_28
#   llvm-openmp        anaconda/osx-64::llvm-openmp-12.0.0-h0dcd299_1
#   patsy              anaconda/osx-64::patsy-0.5.2-py39hecd8cb5_1
#   pooch              anaconda/noarch::pooch-1.4.0-pyhd3eb1b0_0
#   pyopenssl          anaconda/noarch::pyopenssl-22.0.0-pyhd3eb1b0_0
#   pysocks            anaconda/osx-64::pysocks-1.7.1-py39hecd8cb5_0
#   requests           anaconda/noarch::requests-2.27.1-pyhd3eb1b0_0
#   scipy              pkgs/main/osx-64::scipy-1.10.1-py39hf241641_1
#   statsmodels        anaconda/osx-64::statsmodels-0.13.2-py39hca72f7f_0
#   urllib3            anaconda/osx-64::urllib3-1.26.9-py39hecd8cb5_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    pkgs/main::ca-certificates-2023.05.30~ --> anaconda::ca-certificates-2022.4.26-hecd8cb5_0
#
#
#
# Downloading and Extracting Packages
# requests-2.27.1      | 52 KB     |                                       |   0%
# appdirs-1.4.4        | 12 KB     |                                       |   0%
#
# patsy-0.5.2          | 378 KB    |                                       |   0%
#
#
# pyopenssl-22.0.0     | 49 KB     |                                       |   0%
#
#
#
# urllib3-1.26.9       | 178 KB    |                                       |   0%
#
#
#
#
# charset-normalizer-2 | 33 KB     |                                       |   0%
#
#
#
#
#
# pooch-1.4.0          | 41 KB     |                                       |   0%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   |                                       |   0%
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 359 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# llvm-openmp-12.0.0   | 300 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.2 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 30 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.6.15    | 157 KB    |                                       |   0%
#
#
# pyopenssl-22.0.0     | 49 KB     | ############1                         |  33%
# appdirs-1.4.4        | 12 KB     | ##################################### | 100%
#
# patsy-0.5.2          | 378 KB    | #5                                    |   4%
#
#
#
# urllib3-1.26.9       | 178 KB    | ###3                                  |   9%
#
#
#
#
#
# requests-2.27.1      | 52 KB     | ###########2                          |  31%
#
#
#
#
# charset-normalizer-2 | 33 KB     | #################8                    |  48%
#
#
# pyopenssl-22.0.0     | 49 KB     | ##################################### | 100%
#
#
# pyopenssl-22.0.0     | 49 KB     | ##################################### | 100%
# appdirs-1.4.4        | 12 KB     | ##################################### | 100%
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 359 KB    | #6                                    |   4%
#
#
#
#
#
#
#
#
# llvm-openmp-12.0.0   | 300 KB    | #9                                    |   5%
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.2 MB    | 4                                     |   1%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 30 KB     | ###################4                  |  53%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   | ####3                                 |  12%
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##################################### | 100%
#
#
#
#
#
# pooch-1.4.0          | 41 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.6.15    | 157 KB    | ###7                                  |  10%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   | ############6                         |  34%
#
#
#
#
#
#
#
#
#
#
#
# requests-2.27.1      | 52 KB     | ##################################### | 100%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   | ##################7                   |  51%
#
# patsy-0.5.2          | 378 KB    | ##################################### | 100%
#
# patsy-0.5.2          | 378 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ##2                                   |   6%
#
#
#
# urllib3-1.26.9       | 178 KB    | ##################################### | 100%
#
#
#
# urllib3-1.26.9       | 178 KB    | ##################################### | 100%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   | #########################             |  68%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | #####1                                |  14%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ######9                               |  19%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   | ##############################9       |  84%
#
#
#
#
# charset-normalizer-2 | 33 KB     | ##################################### | 100%
#
#
#
#
# charset-normalizer-2 | 33 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ##########8                           |  29%
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 359 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# brotlipy-0.7.0       | 359 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# llvm-openmp-12.0.0   | 300 KB    | ##################################### | 100%
# llvm-openmp-12.0.0   | 300 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# pysocks-1.7.1        | 30 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ###############3                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.6.15    | 157 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ###################9                  |  54%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ########################2             |  66%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ##################################3   |  93%
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# cryptography-37.0.1  | 1.2 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.10.1         | 21.1 MB   | ##################################### | 100%
#
#
#
#
#
#
# statsmodels-0.13.2   | 10.7 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.3.0-cp39-cp39-macosx_10_9_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 31.6 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: numpy>=1.17.3 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from scikit-learn) (1.25.0)
# Requirement already satisfied: scipy>=1.5.0 in /Users/ashleybodine/anaconda3/envs/modeling/lib/python3.9/site-packages (from scikit-learn) (1.10.1)
# Collecting joblib>=1.1.1 (from scikit-learn)
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 6.2 MB/s eta 0:00:0000:01
# Collecting threadpoolctl>=2.0.0 (from scikit-learn)
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.3.1 scikit-learn-1.3.0 threadpoolctl-3.1.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Load the data

# %%
data = pd.read_csv('1.01.+Simple+linear+regression.csv')

# %%
data
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
data.describe()
# Out:
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %% [markdown]
# # Create your first regression

# %% [markdown]
# ## Define the dependent and the independent variables

# %%
y = data ['GPA']
x1 = data ['SAT']

# %% [markdown]
# ## Explore the data

# %%
plt.scatter(x1,y)
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %% [markdown]
# ## Regression itself

# %%
x = sm.add_constant(x1)
results = sm.OLS(y,x).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    GPA   R-squared:                       0.406
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     56.05
# Date:                Mon, 10 Jul 2023   Prob (F-statistic):           7.20e-11
# Time:                        14:46:26   Log-Likelihood:                 12.672
# No. Observations:                  84   AIC:                            -21.34
# Df Residuals:                      82   BIC:                            -16.48
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2750      0.409      0.673      0.503      -0.538       1.088
# SAT            0.0017      0.000      7.487      0.000       0.001       0.002
# ==============================================================================
# Omnibus:                       12.839   Durbin-Watson:                   0.950
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               16.155
# Skew:                          -0.722   Prob(JB):                     0.000310
# Kurtosis:                       4.590   Cond. No.                     3.29e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.29e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 92,
fig = plt.plot(x1,yhat, lw=4, c='orange', label ='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0.0017*x1 + 0
fig = plt.plot(x1,yhat, lw=4, c='green', label ='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.xlim(0)
plt.ylim(0)
plt.show()

# %%
plt.scatter(x1,y)
yhat = 0*x1 + 0.275
fig = plt.plot(x1,yhat, lw=4, c='red', label ='regression line')
plt.xlabel('SAT', fontsize = 20)
plt.ylabel('GPA', fontsize = 20)
plt.show()
